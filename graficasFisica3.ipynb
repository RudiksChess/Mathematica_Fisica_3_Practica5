# %%
data1 = Import["/Users/rudiks/Desktop/1.csv"]
# Out:
# {{x, y, v}, {1, 2.5, 7.2588}, {1, 3.5, 6.65}, {1, 4.5, 6.047}, {1, 5.5, 5.446},
#
# >   {1, 6.5, 4.851}, {1, 7.5, 4.265}, {1, 8.5, 3.607}, {1, 9.5, 2.894},
#
# >   {1, 10.5, 2.142}, {4, 2.5, 7.818}, {4, 3.5, 7.136}, {4, 4.5, 6.389},
#
# >   {4, 5.5, 5.604}, {4, 6.5, 4.805}, {4, 7.5, 3.999}, {4, 8.5, 3.213}, {4, 9.5, 2.374},
#
# >   {4, 10.5, 1.648}, {7, 2.5, 8.942}, {7, 3.5, 7.841}, {7, 4.5, 6.734},
#
# >   {7, 5.5, 5.714}, {7, 6.5, 4.675}, {7, 7.5, 3.768}, {7, 8.5, 2.853}, {7, 9.5, 1.806},
#
# >   {7, 10.5, 1.331}, {10, 2.5, 7.07}, {10, 3.5, 6.77}, {10, 4.5, 6.129},
#
# >   {10, 5.5, 5.278}, {10, 6.5, 4.448}, {10, 7.5, 3.603}, {10, 8.5, 2.765},
#
# >   {10, 9.5, 1.952}, {10, 10.5, 1.423}, {13, 2.5, 6.05}, {13, 3.5, 6.178},
#
# >   {13, 4.5, 5.594}, {13, 5.5, 4.899}, {13, 6.5, 4.352}, {13, 7.5, 3.684},
#
# >   {13, 8.5, 3.061}, {13, 9.5, 2.519}, {13, 10.5, 1.953}, {15, 2.5, 6.454},
#
# >   {15, 3.5, 6.027}, {15, 4.5, 5.539}, {15, 5.5, 4.962}, {15, 6.5, 4.352},
#
# ...

# %%
ListPlot3D[data1, Axes->True,AxesLabel -> {x, y,V},ViewPoint -> {8, 16, 2},PlotStyle -> {{LightGreen, Dashing[None]}}]
# Out:
# -Graphics3D-

# %%
data2 = Import["/Users/rudiks/Desktop/2.csv"]
# Out:
# {{X, Y, V}, {2, 2.5, 7.509}, {2, 3.5, 6.961}, {2, 4.5, 6.466}, {2, 5.5, 5.927},
#
# >   {2, 6.5, 5.541}, {2, 7.5, 5.2}, {2, 8.5, 4.872}, {2, 9.5, 4.6}, {2, 10.5, 4.361},
#
# >   {2, 11.5, 4.17}, {3, 2.5, 7.898}, {3, 3.5, 7.183}, {3, 4.5, 6.552}, {3, 5.5, 5.895},
#
# >   {3, 6.5, 5.419}, {3, 7.5, 5.009}, {3, 8.5, 4.659}, {3, 9.5, 4.362},
#
# >   {3, 10.5, 4.139}, {3, 11.5, 3.952}, {4, 2.5, 8.2}, {4, 3.5, 7.341}, {4, 4.5, 6.569},
#
# >   {4, 5.5, 5.858}, {4, 6.5, 5.269}, {4, 7.5, 4.804}, {4, 8.5, 4.373}, {4, 9.5, 4.028},
#
# >   {4, 10.5, 3.799}, {4, 11.5, 3.678}, {5, 2.5, 8.386}, {5, 3.5, 7.497},
#
# >   {5, 4.5, 6.545}, {5, 5.5, 5.759}, {5, 6.5, 5.07}, {5, 7.5, 4.5}, {5, 8.5, 4.047},
#
# >   {5, 9.5, 3.598}, {5, 10.5, 3.373}, {5, 11.5, 3.288}, {6, 2.5, 8.676},
#
# >   {6, 3.5, 7.592}, {6, 4.5, 6.512}, {6, 5.5, 5.541}, {6, 6.5, 4.79}, {6, 7.5, 4.088},
#
# >   {6, 8.5, 3.5}, {6, 9.5, 3.051}, {6, 10.5, 2.652}, {6, 11.5, 2.695}, {7, 2.5, 9.044},
#
# ...

# %%
ListPlot3D[data2, Axes->True,AxesLabel -> {x, y,V},ViewPoint -> {8, 16, 1.5},PlotStyle -> {{LightGreen, Dashing[None]}}]
# Out:
# -Graphics3D-

# %%
data3 = Import["/Users/rudiks/Desktop/3.csv"]
# Out:
# {{x, y, V}, {1, 0.5, 7.102}, {1, 1.5, 6.976}, {1, 2.5, 6.811}, {1, 3.5, 6.591},
#
# >   {1, 4.5, 6.336}, {1, 5.5, 6.052}, {1, 6.5, 5.757}, {1, 7.5, 5.233}, {1, 8.5, 5.198},
#
# >   {1, 9.5, 4.956}, {1, 10.5, 4.726}, {1, 11.5, 4.512}, {2, 0.5, 7.234},
#
# >   {2, 1.5, 7.089}, {2, 2.5, 6.975}, {2, 3.5, 6.715}, {2, 4.5, 6.441}, {2, 5.5, 6.131},
#
# >   {2, 6.5, 5.818}, {2, 7.5, 5.443}, {2, 8.5, 5.134}, {2, 9.5, 4.738},
#
# >   {2, 10.5, 4.552}, {2, 11.5, 4.312}, {3, 0.5, 7.417}, {3, 1.5, 7.339},
#
# >   {3, 2.5, 7.184}, {3, 3.5, 6.969}, {3, 4.5, 6.638}, {3, 5.5, 6.285}, {3, 6.5, 5.889},
#
# >   {3, 7.5, 5.451}, {3, 8.5, 5.025}, {3, 9.5, 4.661}, {3, 10.5, 4.336},
#
# >   {3, 11.5, 4.008}, {4, 0.5, 7.652}, {4, 1.5, 7.605}, {4, 2.5, 7.503},
#
# >   {4, 3.5, 7.288}, {4, 4.5, 6.971}, {4, 5.5, 6.551}, {4, 6.5, 5.974}, {4, 7.5, 5.433},
#
# >   {4, 8.5, 4.888}, {4, 9.5, 4.389}, {4, 10.5, 3.986}, {4, 11.5, 3.754},
#
# ...

# %%
ListPlot3D[data3, Axes->True,AxesLabel -> {x, y,V},ViewPoint -> {5, -16, 5},PlotStyle -> {{LightGreen, Dashing[None]}}]
# Out:
# -Graphics3D-

# %%
data4 = Import["/Users/rudiks/Desktop/4.csv"]
# Out:
# {{x, y, V}, {15, 11.5, 4.96}, {15, 10.5, 4.931}, {15, 9.5, 4.856}, {15, 8.5, 4.716},
#
# >   {15, 7.5, 4.582}, {15, 6.5, 4.417}, {15, 5.5, 4.235}, {15, 4.5, 4.033},
#
# >   {15, 3.5, 3.787}, {15, 2.5, 3.661}, {14, 11.5, 4.983}, {14, 10.5, 4.792},
#
# >   {14, 9.5, 4.855}, {14, 8.5, 4.741}, {14, 7.5, 4.581}, {14, 6.5, 4.412},
#
# >   {14, 5.5, 4.239}, {14, 4.5, 4.049}, {14, 3.5, 3.814}, {14, 2.5, 3.622},
#
# >   {13, 11.5, 5.112}, {13, 10.5, 5.092}, {13, 9.5, 5.021}, {13, 8.5, 4.884},
#
# >   {13, 7.5, 4.729}, {13, 6.5, 4.543}, {13, 5.5, 4.286}, {13, 4.5, 4.047},
#
# >   {13, 3.5, 3.802}, {13, 2.5, 3.56}, {12, 11.5, 5.33}, {12, 10.5, 5.228},
#
# >   {12, 9.5, 5.299}, {12, 8.5, 5.219}, {12, 7.5, 5.099}, {12, 6.5, 4.678},
#
# >   {12, 5.5, 4.386}, {12, 4.5, 4.119}, {12, 3.5, 3.794}, {12, 2.5, 3.703},
#
# >   {11, 11.5, 5.835}, {11, 10.5, 5.871}, {11, 9.5, 5.841}, {11, 8.5, 5.849},
#
# >   {11, 7.5, 5.843}, {11, 6.5, 5.624}, {11, 5.5, 5.24}, {11, 4.5, 4.772},
#
# ...

# %%
ListPlot3D[data4, Axes->True,AxesLabel -> {x, y,V},ViewPoint -> {8, 7, 8},PlotStyle -> {{LightGreen, Dashing[None]}}]
# Out:
# -Graphics3D-
